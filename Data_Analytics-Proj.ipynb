# %%
import numpy as np
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BigBasket Products.csv')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# Removing Index Column 

df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Use HEad fuction to look first 12 rows

df.head(12)
# Out:
#                                               product                category  \
# 0              Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1                               Water Bottle - Orange  Kitchen, Garden & Pets
# 2                      Brass Angle Deep - Plain, No.2    Cleaning & Household
# 3   Cereal Flip Lid Container/Storage Jar - Assort...    Cleaning & Household
# 4                  Creme Soft Soap - For Hands & Body        Beauty & Hygiene
# 5                   Germ - Removal Multipurpose Wipes    Cleaning & Household
# 6                                        Multani Mati        Beauty & Hygiene
# 7                   Hand Sanitizer - 70% Alcohol Base        Beauty & Hygiene
# 8   Biotin & Collagen Volumizing Hair Shampoo + Bi...        Beauty & Hygiene
# 9                Scrub Pad - Anti- Bacterial, Regular    Cleaning & Household
# 10                           Wheat Grass Powder - Raw    Gourmet & World Food
# ...

# %%
# Data Description

df.describe()
# Out:
#           sale_price  market_price        rating
# count   27549.000000  27555.000000  18919.000000
# mean      334.648391    382.056664      3.943295
# std      1202.102113    581.730717      0.739217
# min         2.450000      3.000000      1.000000
# 25%        95.000000    100.000000      3.700000
# 50%       190.320000    220.000000      4.100000
# 75%       359.000000    425.000000      4.300000
# max    112475.000000  12500.000000      5.000000

# %%
df.describe(include='all')
# Out:
#                              product          category sub_category   brand  \
# count                          27554             27555        27555   27554
# unique                         23540                11           90    2313
# top     Turmeric Powder/Arisina Pudi  Beauty & Hygiene    Skin Care  Fresho
# freq                              26              7867         2294     638
# mean                             NaN               NaN          NaN     NaN
# std                              NaN               NaN          NaN     NaN
# min                              NaN               NaN          NaN     NaN
# 25%                              NaN               NaN          NaN     NaN
# 50%                              NaN               NaN          NaN     NaN
# 75%                              NaN               NaN          NaN     NaN
# max                              NaN               NaN          NaN     NaN
#
# ...

# %%
# Data Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27554 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27554 non-null  object
#  4   sale_price    27549 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        18919 non-null  float64
#  8   description   27440 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.9+ MB

# %%
# Top and Least sold Products. (Frequency)

df['product'].value_counts()
# Out:
# product
# Turmeric Powder/Arisina Pudi                                     26
# Extra Virgin Olive Oil                                           15
# Cow Ghee/Tuppa                                                   14
# Soft Drink                                                       12
# Colorsilk Hair Colour With Keratin                               12
#                                                                  ..
# Pepper & Herb Salami Chicken                                      1
# Nutmeg Powder                                                     1
# Disney Mickey Mouse Plastic Kids Sipper Bottle - Coolest Dude     1
# Chocolates-Roasted Peanut Chocolate                               1
# Green Tea - Pure Original                                         1
# Name: count, Length: 23540, dtype: int64

# %%
# Mesauring Discount on a Certain item.

df['discount'] = df.market_price - df.sale_price

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Find Missing or Null Values.

df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
df['product']  = df['product'].fillna('Unknown')

# %%
df.brand = df.brand.fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# product            0
# category           0
# sub_category       0
# brand              0
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
# Finding the index of missing values under sales price.  (Data Filteration).

df[df.sale_price.isnull()]
# Out:
#                                                 product  \
# 1719            Puja Flower Wicks - Puvvu Vathulu Batti
# 1720                                    Powder - Sambar
# 1721  Steel Fork - Medium, Premium Excel Series, BBCL08
# 1722                                 Snack Mix - Dhokla
# 2401                              Battery AA 3UT Hi Top
# 2402        Klassic Plain Cocktail Napkins (22 X 22 cm)
#
#                       category              sub_category       brand  \
# 1719      Cleaning & Household               Pooja Needs        Jaji
# 1720  Foodgrains, Oil & Masala          Masalas & Spices  Annapoorna
# 1721    Kitchen, Garden & Pets        Crockery & Cutlery     BB Home
# 1722    Snacks & Branded Foods       Ready To Cook & Eat         MTR
# 2401    Kitchen, Garden & Pets  Appliances & Electricals       Nippo
# 2402      Cleaning & Household  Disposables, Garbage Bag     Origami
#
#       sale_price  market_price                     type  rating  \
# ...

# %%
# Filling Sale Price null values with Market Price Values.

df.sale_price = df.sale_price.fillna(df.market_price)

# %%
df.isnull().sum()
# Out:
# product            0
# category           0
# sub_category       0
# brand              0
# sale_price         0
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
df[1718:1725]
# Out:
#                                                 product  \
# 1718                                     Samosa Chutney
# 1719            Puja Flower Wicks - Puvvu Vathulu Batti
# 1720                                    Powder - Sambar
# 1721  Steel Fork - Medium, Premium Excel Series, BBCL08
# 1722                                 Snack Mix - Dhokla
# 1723  Masala Combo - Chicken 15 Gm + Meat 15 Gm + Pu...
# 1724                Powder - Rasam, Karnataka's Iyengar
#
#                       category         sub_category            brand  \
# 1718    Snacks & Branded Foods    Pickles & Chutney  Mother's Recipe
# 1719      Cleaning & Household          Pooja Needs             Jaji
# 1720  Foodgrains, Oil & Masala     Masalas & Spices       Annapoorna
# 1721    Kitchen, Garden & Pets   Crockery & Cutlery          BB Home
# 1722    Snacks & Branded Foods  Ready To Cook & Eat              MTR
# 1723  Foodgrains, Oil & Masala     Masalas & Spices         Kohinoor
# ...

# %%
df.rating = df.rating.fillna(df.rating.median())

# %%
df.description = df.description.fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# discount        0
# dtype: int64

# %%
df.discount = df.discount.fillna(0)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Outliers Detections

sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: xlabel='sale_price'>

# %%
sns.boxplot(df.market_price,orient='h')
# Out:
# <Axes: xlabel='market_price'>

# %%
df[df.sale_price>12000]
# Out:
#                                                  product  \
# 248    4mm Aluminium Induction Base Chapati Roti Tawa...
# 288            Arrabbiata Tomato Pasta Sauce With Chilli
# 436                         Balloon - Polka Dot, 12 Inch
# 1249                                           Beard Kit
# 25301                                    Bravura Clipper
#
#                      category            sub_category       brand  sale_price  \
# 248    Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL    111649.0
# 288      Gourmet & World Food  Sauces, Spreads & Dips   Montanini     22325.0
# 436      Cleaning & Household   Party & Festive Needs    B Vishal     88899.0
# 1249         Beauty & Hygiene          Men's Grooming  Uncle Tony    112475.0
# 25301  Kitchen, Garden & Pets  Pet Food & Accessories        Wahl     12500.0
#
#        market_price                      type  rating  \
# 248          1289.0          Tawa & Sauce Pan     4.1
# ...

# %%
# Remove Unwanted Data. (Mistaked Data)

df.sale_price = np.where(df.sale_price>15000,df.market_price,df.sale_price)

# %%
df[248:250]
# Out:
#                                                product  \
# 248  4mm Aluminium Induction Base Chapati Roti Tawa...
# 249                                    Mix - Rava Idli
#
#                    category          sub_category  brand  sale_price  \
# 248  Kitchen, Garden & Pets  Cookware & Non Stick  HAZEL      1289.0
# 249  Snacks & Branded Foods   Ready To Cook & Eat    Grb       110.0
#
#      market_price                     type  rating  \
# 248        1289.0         Tawa & Sauce Pan     4.1
# 249         110.0  Breakfast & Snack Mixes     4.1
#
#                                            description  discount
# 248  Hazel Aluminium Tawa has an ergonomic design f... -110360.0
# 249  Rava idly is a trendy breakfast recipe and is ...       0.0

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: xlabel='sale_price'>

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
df.category.value_counts()
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: count, dtype: int64

# %%
df.groupby('category')['sale_price'].sum().sort_values(ascending=False)
# Out:
# category
# Beauty & Hygiene            3295574.24
# Kitchen, Garden & Pets      1817723.12
# Gourmet & World Food        1500115.31
# Cleaning & Household         605043.09
# Foodgrains, Oil & Masala     516916.23
# Snacks & Branded Foods       364675.08
# Baby Care                    326317.17
# Beverages                    212186.67
# Bakery, Cakes & Dairy        121525.14
# Eggs, Meat & Fish            101114.12
# Fruits & Vegetables           28345.36
# Name: sale_price, dtype: float64

# %%
df.groupby('category')['sale_price'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
# Explore Sub category

df.groupby('category')['sub_category'].value_counts().head(60)
# Out:
# category                  sub_category
# Baby Care                 Diapers & Wipes              247
#                           Baby Bath & Hygiene          206
#                           Feeding & Nursing             48
#                           Baby Food & Formula           47
#                           Baby Accessories              37
#                           Mothers & Maternity           24
#                           Atta, Flours & Sooji           1
# Bakery, Cakes & Dairy     Dairy                        385
#                           Cookies, Rusk & Khari        153
#                           Cakes & Pastries             125
#                           Breads & Buns                 48
#                           Ice Creams & Desserts         48
#                           Gourmet Breads                35
#                           Non Dairy                     32
#                           Bakery Snacks                 25
# ...

# %%
df.groupby(['category','sub_category'])['sale_price'].sum().head(60)
# Out:
# category                  sub_category
# Baby Care                 Atta, Flours & Sooji           300.00
#                           Baby Accessories             15157.00
#                           Baby Bath & Hygiene          86332.27
#                           Baby Food & Formula          16974.15
#                           Diapers & Wipes             183251.76
#                           Feeding & Nursing            12892.00
#                           Mothers & Maternity          11409.99
# Bakery, Cakes & Dairy     Bakery Snacks                 2611.21
#                           Breads & Buns                 3647.74
#                           Cakes & Pastries             18292.25
#                           Cookies, Rusk & Khari        20327.51
#                           Dairy                        57534.08
#                           Gourmet Breads                3760.95
#                           Ice Creams & Desserts         8162.60
# ...

# %%
df.category.value_counts()
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: count, dtype: int64

# %%
df.groupby(['category','sub_category'])['sale_price'].count()
# Out:
# category                sub_category
# Baby Care               Atta, Flours & Sooji           1
#                         Baby Accessories              37
#                         Baby Bath & Hygiene          206
#                         Baby Food & Formula           47
#                         Diapers & Wipes              247
#                                                     ...
# Snacks & Branded Foods  Noodle, Pasta, Vermicelli    122
#                         Pickles & Chutney            162
#                         Ready To Cook & Eat          643
#                         Snacks & Namkeen             500
#                         Spreads, Sauces, Ketchup     305
# Name: sale_price, Length: 99, dtype: int64

# %%
df[df.category=='Baby Care'].sub_category
# Out:
# 58       Baby Bath & Hygiene
# 99           Diapers & Wipes
# 109      Baby Food & Formula
# 165        Feeding & Nursing
# 173          Diapers & Wipes
#                 ...
# 27372      Feeding & Nursing
# 27383    Baby Bath & Hygiene
# 27406      Feeding & Nursing
# 27446        Diapers & Wipes
# 27468        Diapers & Wipes
# Name: sub_category, Length: 610, dtype: object

# %%
df.groupby(df.category=='Beauty & Hygiene')['sub_category'].count()
# Out:
# category
# False    19688
# True      7867
# Name: sub_category, dtype: int64

# %%
df.sub_category.value_counts()
# Out:
# sub_category
# Skin Care                   2294
# Health & Medicine           1133
# Hair Care                   1028
# Storage & Accessories       1015
# Fragrances & Deos           1000
#                             ...
# Mutton & Lamb                 20
# Water                         17
# Flower Bouquets, Bunches       8
# Pork & Other Meats             5
# Marinades                      1
# Name: count, Length: 90, dtype: int64

# %%
df.groupby(['category','sub_category'])['sale_price'].sum().head(20)
# Out:
# category               sub_category
# Baby Care              Atta, Flours & Sooji        300.00
#                        Baby Accessories          15157.00
#                        Baby Bath & Hygiene       86332.27
#                        Baby Food & Formula       16974.15
#                        Diapers & Wipes          183251.76
#                        Feeding & Nursing         12892.00
#                        Mothers & Maternity       11409.99
# Bakery, Cakes & Dairy  Bakery Snacks              2611.21
#                        Breads & Buns              3647.74
#                        Cakes & Pastries          18292.25
#                        Cookies, Rusk & Khari     20327.51
#                        Dairy                     57534.08
#                        Gourmet Breads             3760.95
#                        Ice Creams & Desserts      8162.60
#                        Non Dairy                  7188.80
# Beauty & Hygiene       Bath & Hand Wash         228908.00
# ...

# %%
df.groupby(['category','sub_category'])['sale_price'].sum().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='category,sub_category'>

# %%
df.sub_category.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='sub_category'>

# %%
a = df[df.category=='Baby Care']

# %%
a.groupby('sub_category')['sale_price'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='sale_price'>

# %%
df.groupby('category')['discount'].sum().sort_values(ascending=False)
# Out:
# category
# Beauty & Hygiene            477892.98
# Kitchen, Garden & Pets      433491.28
# Gourmet & World Food        158878.64
# Foodgrains, Oil & Masala     98916.77
# Baby Care                    37702.83
# Snacks & Branded Foods       31466.42
# Beverages                    28740.33
# Eggs, Meat & Fish            12928.30
# Bakery, Cakes & Dairy        12831.86
# Fruits & Vegetables           7544.19
# Cleaning & Household          7337.26
# Name: discount, dtype: float64

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...
